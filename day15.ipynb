# %%
Work Title :PHONE STORE (MOBILE SHOP)RECORD MANAGEMENT
    A smart phone dealer in the locality is very worried about his record as his assistance is not serious about the turn over.
    He can't change because
# Out:
#   Input In [1]
#     Work Title :PHONE STORE (MOBILE SHOP)RECORD MANAGEMENT
#          ^
# SyntaxError: invalid syntax

# %%
# phone store (MOBILE STORE)RECORD MANAGEMENT
class mobileStore:
    def __init__(self,PhoneName,Modelno,price):
        self.phonename=PhoneName
        self.modelno=Modelno
        self.price=price

    def getprice(self):
        return self.price
    def getmodel(self):
        return self.Model
    def __str__(self):
        return self.PhoneName + ':'+str(self.getmodel())+'::'+ str(self.getprice())
def prices(rec,PhoneName,Modelno,price):
    rec.append(phone(PhoneName,Modelno,price))
    return rec
record=[]
x=input('enter Y as yes and N as no to enter phone details ')
while x=='Y':
    PhoneName=input('phone number:')
    Modelno =input('Model no:')
    money  =input('price:')
    record =prices(record,PhoneName,money)
    x=input('enter Y as yes and N as no to enter phone details')
n =1
print("----- The list of the phone that the store have----")
for item in record:
    print(n,'.',item)
    n=n+1
# Out:
# enter Y as yes and N as no to enter phone details N
# ----- The list of the phone that the store have----

# %% [markdown]
# ### file and writing

# %%
file =open('demo.doc','w')
file.write("'Work title:I need a warm bath and a body massage also a good treat and trip to SA'")
file.close()

# %%
file1=open('day12.ipynb','r')
print(file1.read())
file1.close()
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "id": "97faab68",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import pymysql"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "id": "99cf5602",
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "('information_schema',)\n",
#       "('mysql',)\n",
#       "('performance_schema',)\n",
#       "('sakila',)\n",
#       "('schoolmanagementsystem',)\n",
#       "('sys',)\n",
#       "('techbros',)\n",
#       "('world',)\n"
#      ]
#     }
#    ],
#    "source": [
#     "mydb  =pymysql.connect(\n",
#     "      host = 'localhost',\n",
#     "      user = 'root',\n",
#     "     password = '1234'\n",
#     ") \n",
#     "mycursor =mydb.cursor()\n",
#     "mycursor.execute('SHOW DATABASES')\n",
#     "for x in mycursor:\n",
#     "    print(x)"
#    ]
#   },
#   {
# ...

# %%
file2= open('demo.doc','a')
file2.write('"grace got me covered"')
file.close()

# %%
file3 =open('demo.doc','r+')
print('file3.read')
file3.write("'i love Germany'")
file.close()
# Out:
# file3.read
